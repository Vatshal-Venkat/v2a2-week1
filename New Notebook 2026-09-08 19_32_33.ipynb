# %%
# %sql
GRANT SELECT ON TABLE workspace.default.ml_model_results
TO `vaishnavi8022@gmail.com`;

GRANT SELECT ON TABLE workspace.default.ml_feature_importance
TO `vaishnavi8022@gmail.com`;

GRANT SELECT ON TABLE workspace.default.ml_validation_predictions
TO `vaishnavi8022@gmail.com`;

GRANT SELECT ON TABLE workspace.default.ml_test_predictions
TO `vaishnavi8022@gmail.com`;
